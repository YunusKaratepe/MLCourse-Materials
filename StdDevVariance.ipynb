# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 30.0, 20000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 1000.3817623814962

# %%
incomes.mean()
# Out:
# 99.84656864552127

# %%
incomes.var()
# Out:
# 1000763.6705055082

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?

# %%
probs = []
for j in range(10):
    incomes = np.random.normal(100.0, 30.0, 20000)
    count = 0.0
    for i in incomes:
        if i > (incomes.mean() + incomes.std()) and i < (incomes.mean() + 2*incomes.std()):
            count += 1

    probs.append(count / len(incomes))

print("All probs: ", probs)
print("Probs mean: ", np.mean(probs))
# Out:
# All probs:  [0.1373, 0.1373, 0.1374, 0.1342, 0.1362, 0.138, 0.1394, 0.1356, 0.13525, 0.1349]
# Probs mean:  0.13655500000000004
